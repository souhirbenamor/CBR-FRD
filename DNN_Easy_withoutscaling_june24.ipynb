# %% [markdown]
# <a href="https://colab.research.google.com/github/souhirbenamor/CBR-FRD/blob/main/DNN_Easy_withoutscaling_june24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !pip install gitpython
# Out:
# Collecting gitpython
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.4 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.9 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 smmap-5.0.1

# %%
import os
from git.repo.base import Repo
Repo.clone_from("https://github.com/jeslago/epftoolbox", "epftoolbox")
# Out:
# <git.repo.base.Repo '/content/epftoolbox/.git'>

# %%
cd epftoolbox
# Out:
# /content/epftoolbox

# %%
#from epftoolbox.data import read_data
#df_train, df_test = read_data(path='.', dataset='EPF_data', begin_test_date='28-12-2015',end_test_date='31-12-2016')

# %%
#df_train
# Out:
#                      Price  Exogenous 1  Exogenous 2
# Date
# 2011-01-09 00:00:00  18.29        40242       8280.0
# 2011-01-09 01:00:00  16.04        39159       8413.0
# 2011-01-09 02:00:00  14.60        38825       8502.0
# 2011-01-09 03:00:00  14.95        38969       8669.0
# 2011-01-09 04:00:00  14.50        39093       8849.0
# ...                    ...          ...          ...
# 2015-12-27 19:00:00  35.69        65864      23686.0
# 2015-12-27 20:00:00  35.09        62098      23236.0
# 2015-12-27 21:00:00  32.95        59293      22718.0
# 2015-12-27 22:00:00  27.22        55256      22390.0
# 2015-12-27 23:00:00  26.56        50849      22086.0
#
# [43536 rows x 3 columns]

# %%
#df_test
# Out:
#                      Price  Exogenous 1  Exogenous 2
# Date
# 2015-12-28 00:00:00  25.95        47965     21729.00
# 2015-12-28 01:00:00  23.30        47262     21491.00
# 2015-12-28 02:00:00  19.01        47679     21549.00
# 2015-12-28 03:00:00  24.59        48870     22197.00
# 2015-12-28 04:00:00  25.03        52302     23355.00
# ...                    ...          ...          ...
# 2016-12-31 19:00:00  40.25        59627     19911.50
# 2016-12-31 20:00:00  33.15        56876     20879.50
# 2016-12-31 21:00:00  30.39        54637     21307.75
# 2016-12-31 22:00:00  25.85        50930     21778.25
# 2016-12-31 23:00:00   1.59        45437     27305.00
#
# [8880 rows x 3 columns]

# %%
#from epftoolbox.data import DataScaler
#Xtrain = df_train.values
#Xtest = df_train.values
#scaler = DataScaler('Norm')
#Xtrain_scaled = scaler.fit_transform(Xtrain)
#Xtest_scaled = scaler.transform(Xtest)
#Xtrain_inverse = scaler.inverse_transform(Xtrain_scaled)
#Xtest_inverse = scaler.inverse_transform(Xtest_scaled)
#Xtrain[:3,:]
# Out:
# array([[1.8290e+01, 4.0242e+04, 8.2800e+03],
#        [1.6040e+01, 3.9159e+04, 8.4130e+03],
#        [1.4600e+01, 3.8825e+04, 8.5020e+03]])

# %%
#Xtrain_scaled[:3,:]
# Out:
# array([[0.50536426, 0.22711934, 0.13419524],
#        [0.49770103, 0.20483539, 0.13649405],
#        [0.49279657, 0.19796296, 0.13803236]])

# %%
#Xtrain_inverse[:3,:]
# Out:
# array([[1.8290e+01, 4.0242e+04, 8.2800e+03],
#        [1.6040e+01, 3.9159e+04, 8.4130e+03],
#        [1.4600e+01, 3.8825e+04, 8.5020e+03]])

# %%
 #Xtest[:3,:]
# Out:
# array([[1.8290e+01, 4.0242e+04, 8.2800e+03],
#        [1.6040e+01, 3.9159e+04, 8.4130e+03],
#        [1.4600e+01, 3.8825e+04, 8.5020e+03]])

# %%
#Xtest_scaled[:3,:]
# Out:
# array([[0.50536426, 0.22711934, 0.13419524],
#        [0.49770103, 0.20483539, 0.13649405],
#        [0.49279657, 0.19796296, 0.13803236]])

# %%
#Xtest_inverse[:3,:]
# Out:
# array([[1.8290e+01, 4.0242e+04, 8.2800e+03],
#        [1.6040e+01, 3.9159e+04, 8.4130e+03],
#        [1.4600e+01, 3.8825e+04, 8.5020e+03]])

# %%
#from epftoolbox.data import scaling
#Xtrain = df_train.values
#Xtest = df_train.values
#[Xtrain_scaled, Xtest_scaled], scaler = scaling([Xtrain,Xtest],'Norm')
#Xtrain[:3,:]
# Out:
# array([[1.8290e+01, 4.0242e+04, 8.2800e+03],
#        [1.6040e+01, 3.9159e+04, 8.4130e+03],
#        [1.4600e+01, 3.8825e+04, 8.5020e+03]])

# %%
#Xtrain_scaled[:3,:]
# Out:
# array([[0.50536426, 0.22711934, 0.13419524],
#        [0.49770103, 0.20483539, 0.13649405],
#        [0.49279657, 0.19796296, 0.13803236]])

# %%
#Xtest[:3,:]
# Out:
# array([[1.8290e+01, 4.0242e+04, 8.2800e+03],
#        [1.6040e+01, 3.9159e+04, 8.4130e+03],
#        [1.4600e+01, 3.8825e+04, 8.5020e+03]])

# %%
#Xtest_scaled[:3,:]
# Out:
# array([[0.50536426, 0.22711934, 0.13419524],
#        [0.49770103, 0.20483539, 0.13649405],
#        [0.49279657, 0.19796296, 0.13803236]])

# %%
#type(scaler)
# Out:
# epftoolbox.data._wrangling.DataScaler

# %%
import pandas as pd
import numpy as np
import argparse
import os

from epftoolbox.data import read_data
from epftoolbox.evaluation import MAE, sMAPE
from epftoolbox.models import LEAR

# %%
from epftoolbox.models import evaluate_lear_in_test_dataset
import os

# Market under study. If it not one of the standard ones, the file name
# has to be provided, where the file has to be a csv file
dataset = 'EPF_data_FUND'

# %%
# Number of years (a year is 364 days) in the test dataset.
years_test = 2.0195

# Number of days used in the training dataset for recalibration
calibration_window = 364 * 4

# Optional parameters for selecting the test dataset, if either of them is not provided,
# the test dataset is built using the years_test parameter. They should either be one of
# the date formats existing in python or a string with the following format
# "%d/%m/%Y %H:%M"
begin_test_date = '05/01/2015'
end_test_date = '08/01/2017'

# %%
path_datasets_folder = os.path.join('.', 'datasets')
path_recalibration_folder = os.path.join('.', 'experimental_files')

# %%
dataset
# Out:
# 'EPF_data_FUND'

# %%
EPF_1=pd.read_excel('/content/EPF_data_FUND.xlsx')
EPF_1.reset_index(inplace=True)
EPF_1["Date"] = pd.to_datetime(EPF_1["Date"])
EPF_1 = EPF_1.set_index('Date')
del EPF_1['index']
EPF_1.head()
print(EPF_1)
# Out:
#                      Price  Exogenous 1  Exogenous 2  Exogenous 3  \
# Date
# 2011-01-09 00:00:00  18.29     40242.25      8280.00          0.0
# 2011-01-09 01:00:00  16.04     39158.50      8412.75          0.0
# 2011-01-09 02:00:00  14.60     38824.50      8502.25          0.0
# 2011-01-09 03:00:00  14.95     38969.25      8668.50          0.0
# 2011-01-09 04:00:00  14.50     39092.75      8849.25          0.0
# ...                    ...          ...          ...          ...
# 2017-01-08 19:00:00  56.70     49516.00      8053.50          0.0
# 2017-01-08 20:00:00  52.44     47747.50      7456.50          0.0
# 2017-01-08 21:00:00  51.86     47761.75      6902.50          0.0
# 2017-01-08 22:00:00  52.26     46222.50      6395.00          0.0
# 2017-01-08 23:00:00  50.87     43520.50      4633.50          0.0
#
#                      Exogenous 4  Exogenous 5  Exogenous 6
# Date
# 2011-01-09 00:00:00        21.30        55.17         7.27
# 2011-01-09 01:00:00        21.30        55.17         7.27
# 2011-01-09 02:00:00        21.30        55.17         7.27
# 2011-01-09 03:00:00        21.30        55.17         7.27
# 2011-01-09 04:00:00        21.30        55.17         7.27
# ...                          ...          ...          ...
# 2017-01-08 19:00:00        19.12        56.49        32.59
# 2017-01-08 20:00:00        19.12        56.49        32.59
# 2017-01-08 21:00:00        19.12        56.49        32.59
# 2017-01-08 22:00:00        19.12        56.49        32.59
# 2017-01-08 23:00:00        19.12        56.67        32.59
#
# [52608 rows x 7 columns]

# %%
EPF_1.to_csv('/content/EPF_data_FUND.csv')

# %%
evaluate_lear_in_test_dataset(path_recalibration_folder=path_recalibration_folder,
                             path_datasets_folder=path_datasets_folder, dataset=dataset, years_test=years_test,
                             calibration_window=calibration_window, begin_test_date=begin_test_date,
                             end_test_date=end_test_date)

# %%
#Download available forecast
import pandas as pd
import numpy as np
forecast = pd.read_csv('/content/DNN_forecast_nl2_datEPF_data_FUND_YT2_SFH1_CW4_1.csv')
forecast.reset_index(inplace=True)
forecast['Date'] = pd.to_datetime(forecast['Date'])
forecast = forecast.set_index('Date')
print(forecast)
# Out:
#             index         h0         h1         h2         h3         h4  \
# Date
# 2015-01-05      0  52.524490  52.307251  50.125324  49.432526  50.619846
# 2015-01-06      1  47.385544  45.847050  43.772530  41.550869  39.690052
# 2015-01-07      2  13.901939  11.040697  10.522589  14.025076   6.528306
# 2015-01-08      3  45.624828  43.957352  42.033607  38.925316  38.949963
# 2015-01-09      4  17.446760  14.383570  12.500952  12.347016   4.955743
# ...           ...        ...        ...        ...        ...        ...
# 2017-01-04    730 -19.030592 -22.420105 -22.545885 -18.618797 -18.941229
# 2017-01-05    731  17.126963  18.152449  18.746807  20.872953  25.401163
# 2017-01-06    732  39.384991  37.950600  36.756580  36.797977  37.437393
# 2017-01-07    733  37.008183  36.496876  35.035561  36.730560  39.162968
# 2017-01-08    734  39.664875  37.951450  37.144596  36.982727  36.517395
#
#                    h5         h6         h7         h8  ...        h14  \
# Date                                                    ...
# 2015-01-05  57.325565  66.923859  74.843887  74.187050  ...  68.896942
# 2015-01-06  41.538586  48.950245  55.252743  57.568188  ...  46.869972
# 2015-01-07   5.008758   9.290708  18.995365  23.203087  ...  42.749931
# 2015-01-08  41.307491  50.717033  59.343006  63.588535  ...  57.320812
# 2015-01-09   2.780563   7.946262  13.419364  14.433477  ...  15.357071
# ...               ...        ...        ...        ...  ...        ...
# 2017-01-04 -18.421024 -12.911772 -10.412840  -6.237013  ...  13.109500
# 2017-01-05  33.079304  39.927284  42.470692  44.566589  ...  52.041080
# 2017-01-06  45.319046  54.173561  61.741417  61.433842  ...  54.450539
# 2017-01-07  42.779129  50.078243  54.510948  57.295551  ...  58.562328
# 2017-01-08  40.009911  44.923866  50.125019  52.560020  ...  56.768494
#
#                   h15        h16        h17        h18        h19        h20  \
# Date
# 2015-01-05  70.121994  73.393654  70.746834  67.360359  60.391464  55.096588
# 2015-01-06  47.240490  50.135757  48.475517  46.105530  39.531086  34.905773
# 2015-01-07  48.740047  57.469059  55.913189  55.632687  53.915363  53.730900
# 2015-01-08  55.469055  57.593693  54.074608  49.837444  44.530544  40.944736
# 2015-01-09  17.714827  24.672085  24.184504  22.682566  17.102865  13.781325
# ...               ...        ...        ...        ...        ...        ...
# 2017-01-04  20.647791  29.775061  35.760273  38.558189  37.238964  37.052467
# 2017-01-05  50.392574  53.792290  51.590858  47.762455  47.194962  42.149445
# 2017-01-06  56.703354  60.506481  59.416077  55.524757  49.786228  44.609402
# 2017-01-07  60.010292  64.752472  64.039459  59.885124  53.136696  48.418335
# 2017-01-08  58.821327  64.377609  63.934780  60.767933  55.305237  52.480267
#
#                   h21        h22        h23
# Date
# 2015-01-05  54.104832  48.674118  47.183182
# 2015-01-06  34.797878  30.941771  29.161898
# 2015-01-07  52.804443  47.858063  46.938927
# 2015-01-08  40.470856  33.892796  32.087662
# 2015-01-09  13.478523  10.057911   7.795123
# ...               ...        ...        ...
# 2017-01-04  36.097054  30.945335  28.645769
# 2017-01-05  40.491772  39.690994  38.682095
# 2017-01-06  44.437748  39.629753  38.650871
# 2017-01-07  46.876709  42.800835  41.539959
# 2017-01-08  50.973400  47.448658  45.720261
#
# [735 rows x 25 columns]

# %%
forecast=forecast.iloc[:, 1:]
df=forecast.stack()
df.to_excel("forecast_LEAR_2.xlsx", header=True)
print(df)
# Out:
# Date
# 2015-01-05  h0     52.524490
#             h1     52.307251
#             h2     50.125324
#             h3     49.432526
#             h4     50.619846
#                      ...
# 2017-01-08  h19    55.305237
#             h20    52.480267
#             h21    50.973400
#             h22    47.448658
#             h23    45.720261
# Length: 17640, dtype: float64

# %%
df
# Out:
# Date
# 2015-01-05  h0     52.524490
#             h1     52.307251
#             h2     50.125324
#             h3     49.432526
#             h4     50.619846
#                      ...
# 2017-01-08  h19    55.305237
#             h20    52.480267
#             h21    50.973400
#             h22    47.448658
#             h23    45.720261
# Length: 17640, dtype: float64

# %%
df.to_excel("forecast_LEAR_2.xlsx", header=True)

# %% [markdown]
# DNN

# %% [markdown]
# Hyperparameter

# %%
from epftoolbox.models import hyperparameter_optimizer

# Number of layers in DNN
nlayers = 2

# Market under study. If it not one of the standard ones, the file name
# has to be provided, where the file has to be a csv file
dataset = 'EPF_data_FUND'

# Number of years (a year is 364 days) in the test dataset.
years_test = 2

# Optional parameters for selecting the test dataset, if either of them is not provided,
# the test dataset is built using the years_test parameter. They should either be one of
# the date formats existing in python or a string with the following format
# "%d/%m/%Y %H:%M"
begin_test_date = '05/01/2015'
end_test_date = '08/01/2017'
# Boolean that selects whether the validation and training datasets are shuffled
shuffle_train = 1

# Boolean that selects whether a data augmentation technique for DNNs is used
data_augmentation = 0

# Boolean that selects whether we start a new hyperparameter optimization or we restart an existing one
new_hyperopt = 1

# Number of years used in the training dataset for recalibration
calibration_window = 4

# Unique identifier to read the trials file of hyperparameter optimization
experiment_id = 1

# Number of iterations for hyperparameter optimization
max_evals = 1500

path_datasets_folder = "./datasets/"
path_hyperparameters_folder = "./experimental_files/"

# %%
# Check documentation of the hyperparameter_optimizer for each of the function parameters
# In this example, we optimize a model for the PJM market.
# We consider two directories, one for storing the datasets and the other one for the experimental files.
# We start a hyperparameter optimization from scratch. We employ 1500 iterations in hyperopt,
# 2 years of test data, a DNN with 2 hidden layers, a calibration window of 4 years,
# we avoid data augmentation,  and we provide an experiment_id equal to 1
hyperparameter_optimizer(path_datasets_folder=path_datasets_folder,
                         path_hyperparameters_folder=path_hyperparameters_folder,
                         new_hyperopt=new_hyperopt, max_evals=max_evals, nlayers=nlayers, dataset=dataset,
                         years_test=years_test, calibration_window=calibration_window,
                         shuffle_train=shuffle_train, data_augmentation=0, experiment_id=experiment_id,
                         begin_test_date=begin_test_date, end_test_date=end_test_date)
# Out:
# Test datasets: 2015-01-05 00:00:00 - 2017-01-08 23:00:00
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 7.6 | sMAPE: 25.00 %
#
# Best MAE - Test Dataset
#   MAE: 9.8 | sMAPE: 31.86 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 2/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 7.3 | sMAPE: 24.76 %
#
# Best MAE - Test Dataset
#   MAE: 10.4 | sMAPE: 35.30 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 3/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 7.3 | sMAPE: 24.76 %
#
# Best MAE - Test Dataset
#   MAE: 10.4 | sMAPE: 35.30 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 4/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 7.3 | sMAPE: 24.76 %
#
# Best MAE - Test Dataset
#   MAE: 10.4 | sMAPE: 35.30 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 5/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 7.3 | sMAPE: 24.76 %
#
# Best MAE - Test Dataset
#   MAE: 10.4 | sMAPE: 35.30 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 6/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 7/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 8/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 9/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 10/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 11/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 12/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 13/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 14/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 15/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 16/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 17/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 18/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 19/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 20/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 21/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 22/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 23/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 24/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 25/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 26/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 27/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 28/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 29/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 30/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 31/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 32/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 33/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 34/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 35/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 36/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 37/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 38/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 39/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 40/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 41/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 42/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 43/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 44/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 45/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 46/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 47/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 48/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 49/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 50/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 51/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 52/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 53/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 54/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 55/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 56/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 57/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 58/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 59/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 60/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 61/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 62/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 63/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 64/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 65/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 66/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 67/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 68/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 69/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 70/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 71/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 72/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 73/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 74/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 75/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 76/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 77/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 78/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 79/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 80/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 81/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 82/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 83/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 84/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 85/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 86/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# ...
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1476/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1477/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1478/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1479/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1480/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1481/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1482/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1483/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1484/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1485/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1486/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1487/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1488/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1489/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1490/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1491/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1492/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1493/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1494/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1495/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1496/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1497/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1498/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Tested 1499/1500 iterations.
# Best MAE - Validation Dataset
#   MAE: 3.9 | sMAPE: 15.26 %
#
# Best MAE - Test Dataset
#   MAE: 5.2 | sMAPE: 22.32 %
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: divide by zero encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# /content/epftoolbox/epftoolbox/data/_wrangling.py:49: RuntimeWarning: invalid value encountered in divide
#   transformed_data[:, i] = (data[:, i] - self.median[i]) / self.mad[i]
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
from epftoolbox.models import evaluate_dnn_in_test_dataset
import os

# Number of layers in DNN
nlayers = 2

# Market under study. If it not one of the standard ones, the file name
# has to be provided, where the file has to be a csv file
dataset = 'EPF_data_FUND'

# Number of years (a year is 364 days) in the test dataset.
years_test = 2

# Boolean that selects whether the validation and training datasets were shuffled when
# performing the hyperparameter optimization. Note that it does not select whether
# shuffling is used for recalibration as for recalibration the validation and the
# training datasets are always shuffled.
shuffle_train = 1

# Boolean that selects whether a data augmentation technique for DNNs is used
data_augmentation = 0

# Boolean that selects whether we start a new recalibration or we restart an existing one
new_recalibration = 1

# Number of years used in the training dataset for recalibration
calibration_window = 4

# Unique identifier to read the trials file of hyperparameter optimization
experiment_id = 1

# Optional parameters for selecting the test dataset, if either of them is not provided,
# the test dataset is built using the years_test parameter. They should either be one of
# the date formats existing in python or a string with the following format
# "%d/%m/%Y %H:%M"
begin_test_date = '05/01/2015'
end_test_date = '08/01/2017'

# Set up the paths for saving data (this are the defaults for the library)
path_datasets_folder = os.path.join('.', 'datasets')
path_recalibration_folder = os.path.join('.', 'experimental_files')
path_hyperparameter_folder = os.path.join('.', 'experimental_files')

evaluate_dnn_in_test_dataset(experiment_id, path_hyperparameter_folder=path_hyperparameter_folder,
                               path_datasets_folder=path_datasets_folder, shuffle_train=shuffle_train,
                               path_recalibration_folder=path_recalibration_folder,
                               nlayers=nlayers, dataset=dataset, years_test=years_test,
                               data_augmentation=data_augmentation, calibration_window=calibration_window,
                               new_recalibration=new_recalibration, begin_test_date=begin_test_date,
                               end_test_date=end_test_date)
# Out:
# Test datasets: 2015-01-05 00:00:00 - 2017-01-08 23:00:00
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 2015-01-05 - sMAPE: 6.27%  |  MAE: 3.877
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
